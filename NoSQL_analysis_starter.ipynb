# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene':{'$eq':20}}
fields = {}
limit = 1
result = list(establishments.find(query, fields))
# Use count_documents to display the number of documents in the result
resultcount = establishments.count_documents(query)
print(f'There are {resultcount} establishments with a hygiene score of 20.')
# Display the first document in the results using pprint
resultviewlimit = list(establishments.find(query, fields).limit(limit))
pprint(resultviewlimit)
# Out:
# There are 41 establishments with a hygiene score of 20.
# [{'AddressLine1': '5-6 Southfields Road',
#   'AddressLine2': 'Eastbourne',
#   'AddressLine3': 'East Sussex',
#   'AddressLine4': '',
#   'BusinessName': 'The Chase Rest Home',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4613.888288172291,
#   'FHRSID': 110681,
#   'LocalAuthorityBusinessID': '4029',
#   'LocalAuthorityCode': '102',
#   'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#   'LocalAuthorityName': 'Eastbourne',
#   'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'BN21 1BU',
#   'RatingDate': '2021-09-23T00:00:00',
#   'RatingKey': 'fhrs_0_en-gb',
#   'RatingValue': 0,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('656fc5cbfd2665174b1a7226'),
#   'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
# ...

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(result)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  656fc5cbfd2665174b1a7226   110681                  0
# 1  656fc5cbfd2665174b1a75a3   612039                  0
# 2  656fc5cbfd2665174b1a78ad   730933                  0
# 3  656fc5cbfd2665174b1a7aa1   172735                  0
# 4  656fc5cbfd2665174b1a7ab2   172953                  0
# 5  656fc5cbfd2665174b1a8448   512854                  0
# 6  656fc5cbfd2665174b1a8677  1537089                  0
# 7  656fc5cbfd2665174b1a9b95   155648                  0
# 8  656fc5cbfd2665174b1a9fdc  1012883                  0
# 9  656fc5cbfd2665174b1aa7ed   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
querya = {"AddressLine3":{'$regex':"London"},
        'RatingValue': {'$gte':4}}
resulta = list(establishments.find(querya, fields))
# Use count_documents to display the number of documents in the result
resultcounta = establishments.count_documents(querya)
print(f'There are {resultcounta} establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.')
# Display the first document in the results using pprint
resultviewlimita = list(establishments.find(querya, fields).limit(limit))
pprint(resultviewlimita)
# Out:
# There are 1034 establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
# [{'AddressLine1': 'Burger Van',
#   'AddressLine2': 'Wickes',
#   'AddressLine3': 'London Road',
#   'AddressLine4': 'Sittingbourne',
#   'BusinessName': 'Nats Snax',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4618.8604695160675,
#   'FHRSID': 836424,
#   'LocalAuthorityBusinessID': '15/500750/MIXED',
#   'LocalAuthorityCode': '189',
#   'LocalAuthorityEmailAddress': 'EHAdmin@MidKent.gov.uk',
#   'LocalAuthorityName': 'Swale',
#   'LocalAuthorityWebSite': 'http://www.swale.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'ME10 1NU',
#   'RatingDate': '2022-06-21T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('656fc5cbfd2665174b1a7744'),
# ...

# %%
# Convert the result to a Pandas DataFrame
result_dfa = pd.DataFrame(resulta)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_dfa))
# Display the first 10 rows of the DataFrame
result_dfa.head(10)
# Out:
# Rows in DataFrame:  1034
#                         _id   FHRSID  ChangesByServerID  \
# 0  656fc5cbfd2665174b1a7744   836424                  0
# 1  656fc5cbfd2665174b1a7867  1009559                  0
# 2  656fc5cbfd2665174b1a81ad   632021                  0
# 3  656fc5cbfd2665174b1a81be   959816                  0
# 4  656fc5cbfd2665174b1a81e1  1290095                  0
# 5  656fc5cbfd2665174b1a81e9  1048649                  0
# 6  656fc5cbfd2665174b1a84c1  1171761                  0
# 7  656fc5cbfd2665174b1a8d05   512509                  0
# 8  656fc5cbfd2665174b1a8e83  1262211                  0
# 9  656fc5cbfd2665174b1a8ebe  1262211                  0
#
#   LocalAuthorityBusinessID                   BusinessName  \
# 0          15/500750/MIXED                      Nats Snax
# 1           17/500586/FOOD       Sittingbourne Rugby Club
# 2             PI/000023516                  Welcome House
# 3          17/500226/MIXED  The Food Warehouse By Iceland
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000
querygeo = {
    "geocode.latitude" : {"$gte": str(latitude-degree_search), "$lte": str(latitude+degree_search)},
    "geocode.longitude" : {"$gte": str(longitude-degree_search), "$lte": str(longitude+degree_search)},
    "RatingValue": 5
}
sort = [("scores.Hygiene", -1)]
# Print the results
resultgeo = list(establishments.find(querygeo,fields).sort(sort))
pprint(resultgeo)
# Out:
# [{'AddressLine1': '152 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.930146257832,
#   'FHRSID': 1069652,
#   'LocalAuthorityBusinessID': 'PI/000206841',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2020-10-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('656fc5cbfd2665174b1aca2f'),
#   'geocode': {'latitude': '51.4870351', 'longitude': '0.0927429'},
#   'latitude': None,
# ...

# %%
# Convert result to Pandas DataFrame
result_dfgeo = pd.DataFrame(resultgeo)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_dfgeo))
# Display the first 10 rows of the DataFrame
result_dfgeo.head(10)
# Out:
# Rows in DataFrame:  87
#                         _id   FHRSID  ChangesByServerID  \
# 0  656fc5cbfd2665174b1aca2f  1069652                  0
# 1  656fc5cbfd2665174b1acb0b   694606                  0
# 2  656fc5cbfd2665174b1acb1e   695287                  0
# 3  656fc5cbfd2665174b1acb3a   695566                  0
# 4  656fc5cbfd2665174b1acb46   695033                  0
# 5  656fc5cbfd2665174b1acb6e  1298993                  0
# 6  656fc5cbfd2665174b1acbc9   694596                  0
# 7  656fc5cbfd2665174b1acc48  1152320                  0
# 8  656fc5cbfd2665174b1acc4b  1226528                  0
# 9  656fc5cbfd2665174b1acc4d  1031342                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000206841    TIWA N TIWA African Restaurant Ltd
# 1             PI/000116584                  Fineway Cash & Carry
# 2             PI/000182135                     Lucky Food & Wine
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
#2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {'scores.Hygiene': 0}},
    {"$group": {'_id' : '$LocalAuthorityName', "count":{ '$sum':1}}},
    {'$sort':{'count':-1}}
]
pipelinelimten = [
    {"$match": {'scores.Hygiene': 0}},
    {"$group": {'_id' : '$LocalAuthorityName', "count":{ '$sum':1}}},
    {'$sort':{'count':-1}},
    {'$limit':10}
]
pipeline_count = [
    {"$match": {'scores.Hygiene': 0}},
    {"$group": {'_id' : '$LocalAuthorityName', "count":{ '$sum':1}}},
    {'$sort':{'count':-1}},
    { '$count': "Total" }]
resultsgb = establishments.aggregate(pipeline)
resultscount = establishments.aggregate(pipeline_count)
resultslimten = establishments.aggregate(pipelinelimten)
# Print the number of documents in the result
pprint(list(resultscount))
# Print the first 10 results
pprint(list(resultslimten))
# Out:
# [{'Total': 55}]
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_dfg = pd.DataFrame(resultsgb)
# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_dfg))
# Display the first 10 rows of the DataFrame
result_dfg.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
